# %% [markdown]
# ### Objective: Enrich the existing dataset using Spotify API
# ### Dataset: Spotify dataset

# %% [markdown]
# *Importing Libraries*

# %%
import pandas as pd
import time
import base64
import requests
# Out:
# Dataset loaded: 8330 tracks

# %% [markdown]
# *Function to get the access token using the client id and client secret*

# %%
def get_access_token(client_id, client_secret):
    auth_url = "https://accounts.spotify.com/api/token"
    auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode()).decode("ascii")
    headers = {"Authorization": f"Basic {auth_header}"}
    data = {"grant_type": "client_credentials"}

    response = requests.post(auth_url, headers=headers, data=data)
    response.raise_for_status()
    return response.json()["access_token"]

client_id='1e2af1b14f984f8983377350f9634bfc'
client_secret = "2b8b681956024444ef02d8df779fc26p"


# get access token using client id and client secret
access_token = get_access_token(client_id, client_secret)
headers = {"Authorization": f"Bearer {access_token}"}

# %% [markdown]
# *API call for data*

# %%
def enrich_track_metadata(track_id):
    """Fetch only track, artist, and album metadata (skip audio features)."""
    data = {}

    # Track info
    t_res = requests.get(f"https://api.spotify.com/v1/tracks/{track_id}", headers=headers)
    track_info = t_res.json()

    # Artist info
    artist_id = track_info.get("artists", [{}])[0].get("id")
    ar_res = requests.get(f"https://api.spotify.com/v1/artists/{artist_id}", headers=headers)
    artist_info = ar_res.json() if ar_res.status_code == 200 else {}

    # Album info
    album_id = track_info.get("album", {}).get("id")
    al_res = requests.get(f"https://api.spotify.com/v1/albums/{album_id}", headers=headers)
    album_info = al_res.json() if al_res.status_code == 200 else {}

    # Collect only new metadata
    data.update({
        # Artist metadata
        "artist_followers": artist_info.get("followers", {}).get("total"),
        "artist_popularity": artist_info.get("popularity"),

        # Album metadata
        "album_type": album_info.get("album_type"),
        "label": album_info.get("label"),
    })

    print("data",data)
    return data

# %% [markdown]
# *Calling Api function*

# %%
metadata_cols = [ "artist_followers",
    "artist_popularity","album_type","label"
]

save_path = "/content/drive/MyDrive/Spotify_analytics/spotify_final.csv"

# Load your dataset (original or partially enriched)
df = pd.read_csv(save_path)

# Ensure new columns exist
for col in metadata_cols:
    if col not in df.columns:
        df[col] = None

# Loop through rows and enrich only missing metadata
for i, row in df.iterrows():
    track_id = row['track_id']

    # Skip rows already enriched
    if all(pd.notna(row[col]) for col in metadata_cols):
        continue

    print(f"Fetching {track_id}...")

    try:
        new_data = enrich_track_metadata(track_id)

        for col in metadata_cols:
            # Only fill if missing
            if pd.isna(row[col]) and new_data.get(col) is not None:
                df.at[i, col] = new_data[col]

        # Save progress every 10 rows
        if (i + 1) % 10 == 0:
            df.to_csv(save_path, index=False)
            print(f"Progress saved at row {i+1}")

    except Exception as e:
        print(f" Error for track {track_id}: {e}")

# --- Final save ---
df.to_csv(save_path, index=False)
print(" Dataset enriched successfully (audio features untouched).")
# Out:
# Fetching 6yIzxXqgJ4fkTI0HJlPAPQ...
# data {'artist_followers': 2766239, 'artist_popularity': 0, 'album_type': 'single', 'label': ''}
# Progress saved at row 530
# Fetching 1bLz3Mcy1pf1W04KZBWrHk...
# data {'artist_followers': 148872, 'artist_popularity': 44, 'album_type': 'single', 'label': 'Columbia'}
# Fetching 09eSdS5RTgyodJt3krr5AC...
# data {'artist_followers': 955488, 'artist_popularity': 73, 'album_type': 'album', 'label': 'Universal Records'}
# Fetching 7rBMZvgeWnOTHWUh3Pvw51...
# data {'artist_followers': 378579, 'artist_popularity': 45, 'album_type': 'album', 'label': 'Island Mercury'}
# Fetching 4ZpmGpw5L8kG0VNr3Zhgji...
# data {'artist_followers': 2034885, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Fair Trade/Columbia'}
# Progress saved at row 5150
# Fetching 165lX6DbMhTzqODVZKLmkm...
# data {'artist_followers': 1699729, 'artist_popularity': 69, 'album_type': 'album', 'label': 'Roadrunner Records'}
# Fetching 1yFz5j1B9TqIVwblu6QSUi...
# data {'artist_followers': 6895260, 'artist_popularity': 75, 'album_type': 'album', 'label': 'PROSPECT PARK'}
# Fetching 30oTS7bm0aH3p7lqjEIu8q...
# data {'artist_followers': 1074198, 'artist_popularity': 65, 'album_type': 'compilation', 'label': 'Virgin Records'}
# Fetching 75BGF4LC7AOLFfxn6ukZDH...
# data {'artist_followers': 1432575, 'artist_popularity': 63, 'album_type': 'album', 'label': 'Atlantic Records'}
# Fetching 6IqgRdrXDwZeSdSZtFmyTo...
# data {'artist_followers': 170408, 'artist_popularity': 52, 'album_type': 'single', 'label': 'Centricity Music (CEY)'}
# Fetching 4xNfsvj9mOVnMTvHZZ8HNk...
# data {'artist_followers': 2070033, 'artist_popularity': 65, 'album_type': 'album', 'label': 'Universal Records'}
# Fetching 1a6Jt6USVGKzbjYpcKMwPB...
# data {'artist_followers': 1487355, 'artist_popularity': 63, 'album_type': 'album', 'label': 'Geffen'}
# Fetching 3cMliO9emUSa4d1Ap2MbfW...
# data {'artist_followers': 322147, 'artist_popularity': 49, 'album_type': 'album', 'label': 'Outpost'}
# Fetching 3mJXMEOZGSmq1RfQw4y1qN...
# data {'artist_followers': 2492575, 'artist_popularity': 70, 'album_type': 'album', 'label': 'BMG Rights Management (US) LLC'}
# Fetching 2HhWJIrGBUIIakC8t0xLWC...
# data {'artist_followers': 602627, 'artist_popularity': 58, 'album_type': 'album', 'label': 'Warner Records'}
# Progress saved at row 5290
# Fetching 0dxPHMZTI8TWMYRucsAFNd...
# data {'artist_followers': 13790511, 'artist_popularity': 85, 'album_type': 'album', 'label': 'American/Columbia'}
# Fetching 07HYEJfLR6CrvKeLpfrA7r...
# data {'artist_followers': 60892, 'artist_popularity': 49, 'album_type': 'single', 'label': '667055 Records DK'}
# Fetching 5Xhsf1DLA9j2pVyCbqjkLh...
# data {'artist_followers': 1064207, 'artist_popularity': 62, 'album_type': 'single', 'label': 'UMI'}
# Fetching 5feRp0hymeACBAgBdBSTcp...
# data {'artist_followers': 632651, 'artist_popularity': 56, 'album_type': 'single', 'label': 'Dixon Court Records'}
# Fetching 597GRV7fJ030diN3BTWpKS...
# data {'artist_followers': 456394, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Sparrow (SPR)'}
# Fetching 57SDU0fLQmcxziVQMtc0SQ...
# data {'artist_followers': 119033, 'artist_popularity': 45, 'album_type': 'album', 'label': 'Humility City Records / EMPIRE'}
# Fetching 0taM1mwoUfIQrrz3YRJQuM...
# data {'artist_followers': 221686, 'artist_popularity': 56, 'album_type': 'single', 'label': 'Des Rocs'}
# Fetching 0is4yL58CcQ4Gv4WgTGr9N...
# data {'artist_followers': 975562, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Capitol Records (CAP)'}
# Fetching 5tkcQeBaeM1ZoNs2YUOmnz...
# data {'artist_followers': 3804114, 'artist_popularity': 73, 'album_type': 'album', 'label': 'Fantasy Records'}
# Fetching 0FnugIN4Slm0weQqL8OXEM...
# data {'artist_followers': 7792694, 'artist_popularity': 82, 'album_type': 'album', 'label': 'Roadrunner Records'}
# Progress saved at row 5300
# Fetching 27mBHDw4ojlGDnwRCao4le...
# data {'artist_followers': 1717551, 'artist_popularity': 63, 'album_type': 'album', 'label': 'SC Entertainment'}
# Fetching 3dRQNsEd2XuALldd74DuHt...
# data {'artist_followers': 6895260, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Prospect Park'}
# Fetching 2nv6MQwywzHq5ztmXZkSfX...
# data {'artist_followers': 247708, 'artist_popularity': 59, 'album_type': 'single', 'label': 'Live Help LIve / Artium Recordings, LLC'}
# Fetching 1B5Y9I5wPfvD3C2A81A36C...
# data {'artist_followers': 13790511, 'artist_popularity': 85, 'album_type': 'album', 'label': 'American/Columbia'}
# Fetching 36ynI67Vq1Bz52vEIQMWyy...
# data {'artist_followers': 242568, 'artist_popularity': 55, 'album_type': 'single', 'label': 'Peach Tree Rascals'}
# Fetching 6O8Fqxnk5OlOivJHklfkPZ...
# data {'artist_followers': 31443678, 'artist_popularity': 92, 'album_type': 'album', 'label': 'Warner Records'}
# Fetching 73mlvsfJM2qwlDUJxeaatI...
# data {'artist_followers': 1235392, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Parlophone UK'}
# Fetching 39sN48Q2DIbyVK8i8kkqgF...
# data {'artist_followers': 189662, 'artist_popularity': 44, 'album_type': 'album', 'label': 'Flicker Records'}
# Fetching 3v2XiE8ztYHOsrjIBN4Xh2...
# data {'artist_followers': 1468232, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Interscope Records*'}
# Progress saved at row 5440
# Fetching 2MS98sTzH3OsaFS4ZKzqPK...
# data {'artist_followers': 515703, 'artist_popularity': 64, 'album_type': 'single', 'label': 'Pure Noise Records'}
# Fetching 6CHENx8iqzMwavTIz8s0gm...
# data {'artist_followers': 1428468, 'artist_popularity': 65, 'album_type': 'album', 'label': 'DGC'}
# Fetching 4yHLejQxBnufgbFPALQkK3...
# data {'artist_followers': 828432, 'artist_popularity': 56, 'album_type': 'album', 'label': 'Warp Records'}
# Fetching 5JTgqOeHWg4bxMZYMRTE4H...
# data {'artist_followers': 3620685, 'artist_popularity': 72, 'album_type': 'album', 'label': 'Epic/Immortal'}
# Fetching 3lwcrfL6LfZ1p9ZU8KRx4n...
# data {'artist_followers': 188002, 'artist_popularity': 48, 'album_type': 'album', 'label': 'Dualtone Music Group'}
# Fetching 1xJ8RjDucztPOKB0ek95tf...
# data {'artist_followers': 21368384, 'artist_popularity': 86, 'album_type': 'compilation', 'label': 'Columbia'}
# Fetching 3u3zJrKRNNgNEl7rfDHDcN...
# data {'artist_followers': 761504, 'artist_popularity': 54, 'album_type': 'single', 'label': 'Eleven Seven Music'}
# Progress saved at row 5480
# Fetching 72bwwzxhRQN8u6I6R6hwtO...
# data {'artist_followers': 6895260, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Prospect Park'}
# Fetching 0L6BTnS09R0LUCnGpBWo2S...
# data {'artist_followers': 946698, 'artist_popularity': 58, 'album_type': 'album', 'label': 'Third Man Records'}
# Fetching 5cA9fu0qKxeV9mTaDpFjgH...
# data {'artist_followers': 364542, 'artist_popularity': 48, 'album_type': 'album', 'label': 'J Records/Legacy'}
# Fetching 0Cx5QWilR60IyyUvGZQtDC...
# data {'artist_followers': 5124289, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Hollywood Records'}
# Fetching 0W8oh1Zst7Y1GczYEDOIuS...
# data {'artist_followers': 1432575, 'artist_popularity': 63, 'album_type': 'album', 'label': 'Roadrunner Records/Atlantic'}
# Fetching 2XheCI3rWOUChSH5ntgVw9...
# data {'artist_followers': 34488407, 'artist_popularity': 90, 'album_type': 'single', 'label': 'MAU Records'}
# Fetching 3UeTr9z3nVsPVg58IKGHcT...
# data {'artist_followers': 7222881, 'artist_popularity': 82, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 0UVfZ1QfaSPqRHhmZNVI71...
# data {'artist_followers': 764809, 'artist_popularity': 52, 'album_type': 'album', 'label': 'Noname'}
# Fetching 4anzVbFPUuZTw0KQeZ0qnu...
# data {'artist_followers': 11714226, 'artist_popularity': 81, 'album_type': 'album', 'label': 'Rammstein'}
# Fetching 3O2pB9JHreUZ9F83qSNmu8...
# data {'artist_followers': 1319449, 'artist_popularity': 67, 'album_type': 'album', 'label': 'RCA Records Label'}
# Progress saved at row 5490
# Fetching 1HpBm13TNcyMW3PoUrlZPv...
# data {'artist_followers': 741142, 'artist_popularity': 61, 'album_type': 'album', 'label': 'A&M'}
# Fetching 7AsqUKKbPMxOFNIbRLBxHt...
# data {'artist_followers': 2138463, 'artist_popularity': 67, 'album_type': 'album', 'label': 'Geffen'}
# Fetching 19n9s9SfnLtwPEODqk8KCT...
# data {'artist_followers': 1017329, 'artist_popularity': 62, 'album_type': 'album', 'label': 'RRE, LLC / Republic'}
# Fetching 12OkZyDWNBLUqoReoseGrc...
# data {'artist_followers': 3981986, 'artist_popularity': 76, 'album_type': 'album', 'label': 'Metalface'}
# Fetching 2FWmKZ3kNbVsKGhuNHsltW...
# data {'artist_followers': 1184760, 'artist_popularity': 65, 'album_type': 'album', 'label': 'Rhino/Elektra'}
# Fetching 5z0u74IwEWVfWsf6PM1aCY...
# data {'artist_followers': 146508, 'artist_popularity': 48, 'album_type': 'single', 'label': 'DRMCLB / Cosa Nostra Music'}
# Fetching 73M2Vb5MfZh8iGKudkMtlw...
# data {'artist_followers': 873294, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Universal-Island Records Ltd.'}
# Fetching 6Lqqc9jcrXUSxiDA5jle1j...
# data {'artist_followers': 220129, 'artist_popularity': 55, 'album_type': 'single', 'label': 'Vertigo Berlin'}
# Fetching 6b7z3keZ5gDJ2zBnyrke9P...
# data {'artist_followers': 801820, 'artist_popularity': 62, 'album_type': 'album', 'label': 'Carpark Records'}
# Fetching 4z5L0qDduw3w1apQ4Qa6KV...
# data {'artist_followers': 200655, 'artist_popularity': 46, 'album_type': 'single', 'label': 'Quannum Projects'}
# Progress saved at row 5500
# Fetching 3oZUlZMXkj51AyYG8lGaE7...
# data {'artist_followers': 1577340, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Metropolis Records'}
# Fetching 78Gzxi27GuNHTfkn2BylG4...
# data {'artist_followers': 6412506, 'artist_popularity': 78, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 6oKeVXkFW8W91cyoWVgRHE...
# data {'artist_followers': 389238, 'artist_popularity': 66, 'album_type': 'single', 'label': 'EMI'}
# Progress saved at row 5600
# Fetching 2busyK7jKVJaZN4Q6gZqKw...
# data {'artist_followers': 5124289, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Hollywood Records'}
# Fetching 6holGuk1jKHTdWyWBOZi8l...
# data {'artist_followers': 8002709, 'artist_popularity': 82, 'album_type': 'album', 'label': 'Interscope'}
# Fetching 7nLL5UrsXYHVWv2DnXBtud...
# data {'artist_followers': 2352006, 'artist_popularity': 68, 'album_type': 'album', 'label': 'Reunion Records'}
# Fetching 5qaLfqAUiqvsoL0l4T05Yx...
# data {'artist_followers': 7187997, 'artist_popularity': 81, 'album_type': 'album', 'label': 'Universal-Island Records Ltd.'}
# Fetching 6PwDTjmJXS2uMZDrjRZAXK...
# data {'artist_followers': 288632, 'artist_popularity': 53, 'album_type': 'album', 'label': 'Run For Cover Records, LLC'}
# Fetching 0aHoZOnjEzaN0UkypUkXb9...
# data {'artist_followers': 114901, 'artist_popularity': 41, 'album_type': 'album', 'label': 'Glassnote Entertainment Group LLC'}
# Fetching 5M8YrY0L5SWV2Nt7ti98ZW...
# data {'artist_followers': 371960, 'artist_popularity': 56, 'album_type': 'album', 'label': 'Run For Cover Records, LLC'}
# Progress saved at row 5640
# Fetching 2cCWbBmadLbKvr9xddC79R...
# data {'artist_followers': 7792694, 'artist_popularity': 82, 'album_type': 'album', 'label': 'Roadrunner Records'}
# Fetching 4atgiEFQzhuk5P7qYUGymo...
# data {'artist_followers': 455123, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Centricity Music (CEY)'}
# Fetching 2e6Tbu1hiYjUR7kgMIZpkO...
# data {'artist_followers': 267407, 'artist_popularity': 51, 'album_type': 'album', 'label': 'Fair Trade/Columbia'}
# Fetching 16EX0HquvKdjPjP5zljPSG...
# data {'artist_followers': 9561247, 'artist_popularity': 80, 'album_type': 'album', 'label': 'Def Jam Recordings'}
# Fetching 37kTASujIfZZ27NV7PfIrf...
# data {'artist_followers': 23078616, 'artist_popularity': 86, 'album_type': 'album', 'label': 'Warner Records'}
# Fetching 1PQNcWNJt5P9gSLRLA5gmT...
# data {'artist_followers': 119011, 'artist_popularity': 58, 'album_type': 'single', 'label': 'Another Label'}
# Fetching 4kFfFe38CRVnTsakUTL4E4...
# data {'artist_followers': 697564, 'artist_popularity': 51, 'album_type': 'album', 'label': 'SST Records'}
# Progress saved at row 5680
# Fetching 1rgPXmgq1rOwglSwaTrq9S...
# data {'artist_followers': 2088545, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Lava Music/Republic Records'}
# Fetching 0QikKeBIDUlP7ZvsZHP0yO...
# data {'artist_followers': 138613, 'artist_popularity': 53, 'album_type': 'album', 'label': 'LUSTRE'}
# Fetching 4pdPJQqQNWuDQ6Swl2mW2u...
# data {'artist_followers': 328073, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Fearless Records'}
# Fetching 3mhhCui69mtJnRhLDoIi2f...
# data {'artist_followers': 2059873, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Virgin Records'}
# Fetching 6wAWl7nneofDDAE3WI4XNj...
# data {'artist_followers': 144350, 'artist_popularity': 51, 'album_type': 'album', 'label': 'SideOneDummy Records'}
# Fetching 6wIjQNc12WD1EoTlX0VmM6...
# data {'artist_followers': 801820, 'artist_popularity': 62, 'album_type': 'album', 'label': 'Carpark Records'}
# Fetching 1UU3IpxOVpjjHdoQjchpgX...
# data {'artist_followers': 2393844, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Walt Disney Records'}
# Fetching 1ylzYcU6FGnuBqqdqqH7QL...
# data {'artist_followers': 23078616, 'artist_popularity': 86, 'album_type': 'album', 'label': 'Warner Records'}
# Fetching 6VVd4kRfzBsZqFbvEAjloh...
# data {'artist_followers': 113791, 'artist_popularity': 38, 'album_type': 'album', 'label': 'Sumerian Records'}
# Fetching 6XSEz4r6cUwOZgWvE51zDT...
# data {'artist_followers': 1866975, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Zef Records, LLC'}
# Progress saved at row 5690
# Fetching 7dITAq1YP5e0kTcaDq4YWI...
# data {'artist_followers': 3257850, 'artist_popularity': 77, 'album_type': 'album', 'label': 'Ariola'}
# Fetching 2wzsaUL31aQAna0Rnd82mM...
# data {'artist_followers': 423844, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Big Beat Records/Atlantic'}
# Fetching 3MZ7TxuXNnwYXm2KZGap5g...
# data {'artist_followers': 7187997, 'artist_popularity': 81, 'album_type': 'album', 'label': 'EMI'}
# Fetching 7vcDJCAO356RYkCfiUozmE...
# data {'artist_followers': 2944181, 'artist_popularity': 71, 'album_type': 'album', 'label': 'Parlophone Spain'}
# Fetching 1D7UBHqaPWDbBHs2S5YXge...
# data {'artist_followers': 4549502, 'artist_popularity': 77, 'album_type': 'album', 'label': 'Geffen'}
# Fetching 333nLXIkj5thGuWvIymETt...
# data {'artist_followers': 1483569, 'artist_popularity': 68, 'album_type': 'album', 'label': 'TFK Music / The Fuel Music'}
# Fetching 7EdO50H2O5QuqAcEGCKeFY...
# data {'artist_followers': 46386, 'artist_popularity': 46, 'album_type': 'album', 'label': 'Born Without Bones'}
# Fetching 4RU7rnJBOXCzWmsLDqUaFC...
# data {'artist_followers': 23078616, 'artist_popularity': 86, 'album_type': 'album', 'label': 'Warner Records'}
# Progress saved at row 5830
# Fetching 4JwxJm8zCPbc1DMcfVdbBl...
# data {'artist_followers': 11651919, 'artist_popularity': 80, 'album_type': 'album', 'label': 'Capitol Records (US1A)'}
# Fetching 3LHFVQwFLoFLJRd1AFbPTZ...
# data {'artist_followers': 7792694, 'artist_popularity': 82, 'album_type': 'album', 'label': 'Rhino'}
# Fetching 7F0dwqgKzlaIRrngChBRAc...
# data {'artist_followers': 1513966, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Rhino/Warner Records'}
# Fetching 4QbraaiC4oHW1qmWy7M3AI...
# data {'artist_followers': 158294, 'artist_popularity': 49, 'album_type': 'album', 'label': 'NST'}
# Fetching 245q31NvaFNkMw8QRVy23b...
# data {'artist_followers': 35966, 'artist_popularity': 31, 'album_type': 'single', 'label': 'RCA Records Label'}
# Fetching 1JpzpEes2HzdsBZsYRXBxI...
# data {'artist_followers': 380934, 'artist_popularity': 61, 'album_type': 'album', 'label': 'Avant Garden/Island Records'}
# Fetching 5YESYAHcr5GpjheBegwFd4...
# data {'artist_followers': 515703, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Pure Noise Records'}
# Fetching 2jOdqw7a9uV1s256FXXR4W...
# data {'artist_followers': 2088695, 'artist_popularity': 67, 'album_type': 'album', 'label': 'Round Hill Music'}
# Progress saved at row 5870
# Fetching 5IOUNrN8E37eLGdLNRr9aC...
# data {'artist_followers': 417276, 'artist_popularity': 55, 'album_type': 'album', 'label': 'Columbia'}
# Fetching 7fFJ4nfi1mnQ10J8YAu9Di...
# data {'artist_followers': 1324033, 'artist_popularity': 63, 'album_type': 'album', 'label': 'Almo Sounds'}
# Fetching 6trZBfGagQQeI97yJQuq4c...
# data {'artist_followers': 52055, 'artist_popularity': 46, 'album_type': 'single', 'label': 'Cool Company Music LLC'}
# Fetching 3KmuRpdh3UDv9GHyO8SmgB...
# data {'artist_followers': 779828, 'artist_popularity': 63, 'album_type': 'album', 'label': 'Sumerian Records'}
# Progress saved at row 6070
# Fetching 3L19vBWH4jTHNXbuBaHbUN...
# data {'artist_followers': 56498, 'artist_popularity': 41, 'album_type': 'album', 'label': 'Reprise'}
# Fetching 34v7Zs9a64h1xC3PWrmypP...
# data {'artist_followers': 606411, 'artist_popularity': 67, 'album_type': 'single', 'label': 'XL Recordings'}
# Fetching 2CB1boDu1c9FOp09Oylq6r...
# data {'artist_followers': 328692, 'artist_popularity': 51, 'album_type': 'single', 'label': 'UMGRI Interscope'}
# Fetching 4hrJhMznNddR7UThDKHSJy...
# data {'artist_followers': 818758, 'artist_popularity': 62, 'album_type': 'single', 'label': 'dBpm Records'}
# Fetching 6ttg1sxtU12beFZkjoc6j5...
# data {'artist_followers': 1467929, 'artist_popularity': 69, 'album_type': 'album', 'label': 'Interscope'}
# Fetching 0LttzRjJ4kRdDD7PnMuaqg...
# data {'artist_followers': 294951, 'artist_popularity': 52, 'album_type': 'single', 'label': 'Gotee Records'}
# Fetching 2zLZuZFgf4mn3af8wILpHS...
# data {'artist_followers': 409216, 'artist_popularity': 61, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 4daxThR2Ny2xj0hkar6XkX...
# data {'artist_followers': 415289, 'artist_popularity': 63, 'album_type': 'album', 'label': 'Concord Records'}
# Fetching 1yNInj2X42ZqQG6PUE57QV...
# data {'artist_followers': 1072230, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Sparrow (SPR)'}
# Fetching 6zsT60ALu2xeljCWRp3rEs...
# data {'artist_followers': 871677, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Keep Cool/RCA Records'}
# Progress saved at row 6080
# Fetching 3V0W5CfNDMiTKg93wuLFxJ...
# data {'artist_followers': 170029, 'artist_popularity': 56, 'album_type': 'album', 'label': 'Cherrytree Records/Kierszenbaum'}
# Fetching 3q5Zm5NnYcpXKLNmTO1tyo...
# data {'artist_followers': 284525, 'artist_popularity': 52, 'album_type': 'album', 'label': 'Cherrytree Records/Kierszenbaum'}
# Fetching 5j7gLuOsBOyqooruGxX4nx...
# data {'artist_followers': 6042496, 'artist_popularity': 79, 'album_type': 'album', 'label': 'The Bicycle Music Company'}
# Fetching 7A2dius6RtCZDWbJmNe6gQ...
# data {'artist_followers': 1389352, 'artist_popularity': 70, 'album_type': 'album', 'label': 'Reach Records/Columbia'}
# Fetching 1H8BKN1WYV6AW1kghI3ldP...
# data {'artist_followers': 1314627, 'artist_popularity': 76, 'album_type': 'album', 'label': 'Domino Recording Co'}
# Fetching 7cfr3F2jpzjwqL6ZhGfjtH...
# data {'artist_followers': 2061810, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Red Bull Records'}
# Fetching 0jceXOZ2D9ZSzsfl3CKlxg...
# data {'artist_followers': 1267357, 'artist_popularity': 74, 'album_type': 'album', 'label': 'Fair Trade/Columbia'}
# Fetching 3zBuFkWwxbraG7ZlsNc9Hr...
# data {'artist_followers': 279042, 'artist_popularity': 47, 'album_type': 'album', 'label': 'Hardcover/RCA Records'}
# Fetching 4SE81CrzH0qPA8KHqM9Syz...
# data {'artist_followers': 13551592, 'artist_popularity': 89, 'album_type': 'album', 'label': 'XL Recordings'}
# Fetching 6ubqrTIJwspBSqx8XQHN2K...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Progress saved at row 6090
# Fetching 6pzWZe7LIcfKzriMIk6opx...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 5mJ96Y7ZTc7SukGLGFMjEz...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 6ejOqrr7r2LcUDxIqZyygp...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 1TULEHv0wpIZYI7zqmhzEg...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 1ocR8gUE4fBfNJZtBr0TFQ...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 5jsn38ryHgFhcbJgZMQCo0...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 4dW5YBRHvy6PuDl60upoEu...
# data {'artist_followers': 184054, 'artist_popularity': 52, 'album_type': 'album', 'label': 'Atlantic Records UK'}
# Fetching 0ABtEGkZgxAnJOCKVVhr29...
# data {'artist_followers': 632651, 'artist_popularity': 56, 'album_type': 'album', 'label': 'ARIMÉ'}
# Fetching 1nt3853bEskHySwKBClMrn...
# data {'artist_followers': 243427, 'artist_popularity': 50, 'album_type': 'album', 'label': 'Centricity Music (CEY)'}
# Fetching 4O6LLkl0CSpokMLPNVbTc0...
# data {'artist_followers': 12679, 'artist_popularity': 36, 'album_type': 'single', 'label': 'Integrity Music IMR US'}
# Fetching 42Kv1RoTAm09FeytxiuZIB...
# data {'artist_followers': 7585068, 'artist_popularity': 86, 'album_type': 'album', 'label': 'Rhino'}
# Fetching 1mAEQbdq0dZQWfujWG6rCd...
# data {'artist_followers': 2386762, 'artist_popularity': 73, 'album_type': 'album', 'label': 'Tan Cressida/Columbia'}
# Progress saved at row 6200
# Fetching 0YFA0boMX3HBAZS1QfHKRR...
# data {'artist_followers': 7222881, 'artist_popularity': 82, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 4QglwXpVgc088RhQOp42vx...
# data {'artist_followers': 2305407, 'artist_popularity': 62, 'album_type': 'compilation', 'label': 'Epic Soundtrax'}
# Fetching 09jPXOz0LS0kpqmkQRaFPO...
# data {'artist_followers': 2929834, 'artist_popularity': 73, 'album_type': 'album', 'label': 'Geffen'}
# Fetching 7BL20x1o7Xp13doge3OeRP...
# data {'artist_followers': 682682, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Merge Records'}
# Fetching 1V4uZia23KCnh7BfTTsVMu...
# data {'artist_followers': 34488407, 'artist_popularity': 90, 'album_type': 'album', 'label': 'MAU Records'}
# Fetching 0SADXPubFbFXu7ZR3M86io...
# data {'artist_followers': 472057, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Interscope'}
# Fetching 1h20yRsf5WeuHbohrlfcCt...
# data {'artist_followers': 254192, 'artist_popularity': 50, 'album_type': 'album', 'label': 'Island Mercury'}
# Fetching 0IShCbw4JJEpcmZiTwAena...
# data {'artist_followers': 517878, 'artist_popularity': 56, 'album_type': 'album', 'label': 'Tierra Whack'}
# Progress saved at row 6240
# Fetching 1OXzwmEPLq7cR6J6sbcLto...
# data {'artist_followers': 761504, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Epic'}
# Fetching 62NhZM0i7RrAThbBmb2vsQ...
# data {'artist_followers': 186509, 'artist_popularity': 37, 'album_type': 'album', 'label': 'Junglepussy'}
# Fetching 60l2m3BD5VY0HSc3xmSpPI...
# data {'artist_followers': 6174365, 'artist_popularity': 78, 'album_type': 'album', 'label': 'Columbia'}
# Fetching 2yhpa4tgc5SeM6ErBm26fK...
# data {'artist_followers': 1143841, 'artist_popularity': 66, 'album_type': 'album', 'label': 'UMe Direct 2'}
# Fetching 13yFBO0mxphhrphW3s6dx2...
# data {'artist_followers': 280971, 'artist_popularity': 46, 'album_type': 'album', 'label': 'Senaca Village'}
# Fetching 171PWhxgdrIOgcAiBPO3Gr...
# data {'artist_followers': 1064199, 'artist_popularity': 65, 'album_type': 'album', 'label': 'Jet Life Recordings'}
# Fetching 19CmuECYssqkPWANF4nLWM...
# data {'artist_followers': 727807, 'artist_popularity': 64, 'album_type': 'album', 'label': 'EMI Argentina'}
# Fetching 4jhbBCHWjQqWD4cifyuAcA...
# data {'artist_followers': 328073, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Fearless Records'}
# Fetching 2pAho4WqtK5hQtgImHzT74...
# data {'artist_followers': 23078616, 'artist_popularity': 86, 'album_type': 'album', 'label': 'Warner Records'}
# Progress saved at row 6380
# Fetching 4QnKrqFiQwzKXOJ5sOk53u...
# data {'artist_followers': 111400, 'artist_popularity': 37, 'album_type': 'single', 'label': 'Alt. Music Group'}
# Fetching 6z3fmpMqgV3a8DYZgdiU7w...
# data {'artist_followers': 229536, 'artist_popularity': 48, 'album_type': 'album', 'label': 'Yeek Recordings'}
# Fetching 2HIU8kiFo9sB5ih05q8wgP...
# data {'artist_followers': 4876606, 'artist_popularity': 75, 'album_type': 'single', 'label': 'Universal Records'}
# Fetching 2HuSaKSnkvSaRQviRm1glh...
# data {'artist_followers': 252305, 'artist_popularity': 62, 'album_type': 'single', 'label': 'Big Beat/Neon Gold'}
# Fetching 2q1KVUPMs9unSAKHFAaQFg...
# data {'artist_followers': 5124289, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Hollywood Records'}
# Fetching 4O4Y5pZNd0kge9aw95OaYC...
# data {'artist_followers': 3981986, 'artist_popularity': 76, 'album_type': 'album', 'label': 'Rhymesayers'}
# Fetching 5UDoMj8EIEXrQ4N0UR0nos...
# data {'artist_followers': 621671, 'artist_popularity': 61, 'album_type': 'album', 'label': 'Oh Boy Records'}
# Fetching 2LXPNLSMAauNJfnC58lSqY...
# data {'artist_followers': 6864260, 'artist_popularity': 74, 'album_type': 'album', 'label': 'Epic'}
# Fetching 4dmh3OPtAhbEybhGoOG9TE...
# data {'artist_followers': 631586, 'artist_popularity': 62, 'album_type': 'album', 'label': 'Geffen'}
# Fetching 0stxKRK739g6X6Dorzh9a5...
# data {'artist_followers': 876318, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Bar/None Records'}
# Progress saved at row 6390
# Fetching 0wmaGiDKtKaRf7G8nBfNsQ...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 0qHeP8zt2WWef7EWCs1ECj...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 02QPENpZVWiSrrLRXsXNqE...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 0E2UdlzNQP9I70MYumYlFo...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 6HmWy7ttkeZGG2KEtt8AqX...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 3YZ4ccGSysav9mPqbni9JU...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 7twVmetQlugzgUqdMNjdJ4...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Progress saved at row 6430
# Fetching 2k6hpKTyubRVOmQR11ViY3...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 672N8DGGTOLCOgWe0koX5g...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 69Okr5waikbnJWwzfaTQHe...
# data {'artist_followers': 4515259, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Atlantic Records'}
# Fetching 1SByxvzTeuhTtPLWuuO5G8...
# data {'artist_followers': 2976978, 'artist_popularity': 70, 'album_type': 'album', 'label': 'Top Dog/Atlantic'}
# Fetching 2PMLvZHLKQ6iRbxCZgHcQS...
# data {'artist_followers': 31218, 'artist_popularity': 35, 'album_type': 'album', 'label': 'Same Plate Entertainment'}
# Fetching 6GAemDMWAXa8wZOBkO1gar...
# data {'artist_followers': 2389550, 'artist_popularity': 68, 'album_type': 'album', 'label': 'Jive'}
# Fetching 0vDBNWI0uXf7dNkiiX2P5z...
# data {'artist_followers': 284665, 'artist_popularity': 51, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 6631n0cKU7Ak9e0QfXSjn9...
# data {'artist_followers': 151640, 'artist_popularity': 45, 'album_type': 'album', 'label': 'Nettwerk Records'}
# Fetching 4HIKcEKSijQLW5YNLsdLzt...
# data {'artist_followers': 13790511, 'artist_popularity': 85, 'album_type': 'album', 'label': 'American/Columbia'}
# Progress saved at row 6570
# Fetching 4R7kumtHnf5SsKyPYrVO5r...
# data {'artist_followers': 558025, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Matador'}
# Fetching 4c75xeSteTcgSSxRtsKqOJ...
# data {'artist_followers': 2929834, 'artist_popularity': 73, 'album_type': 'album', 'label': 'Virgin Records (US1A)'}
# Fetching 6VSmHLLvYAAkzrYFT3LloU...
# data {'artist_followers': 333356, 'artist_popularity': 55, 'album_type': 'album', 'label': 'Tooth & Nail (TNN)'}
# Fetching 2tu4dVYXtD9D0hUMEHidp9...
# data {'artist_followers': 13390, 'artist_popularity': 34, 'album_type': 'single', 'label': 'KaiL Baxley'}
# Fetching 6fIZxVeVNdjeZjX2Q1YAaA...
# data {'artist_followers': 806196, 'artist_popularity': 62, 'album_type': 'album', 'label': 'Beggars Banquet'}
# Fetching 5f2ZVFERwwh3asebmurZEf...
# data {'artist_followers': 23078616, 'artist_popularity': 86, 'album_type': 'album', 'label': 'Warner Records'}
# Fetching 5PkX5JJ5iBoj3kQG1ZxsKW...
# data {'artist_followers': 882242, 'artist_popularity': 67, 'album_type': 'album', 'label': 'Eleven Seven Music'}
# Progress saved at row 6610
# Fetching 4I5kQyAYTvwHEIiZIP8B2j...
# data {'artist_followers': 558025, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Matador'}
# Fetching 5w4enr0FN8ZTwxmfnACz2f...
# data {'artist_followers': 158294, 'artist_popularity': 49, 'album_type': 'album', 'label': 'NST'}
# Fetching 3xF76F90WnIXCkR2fPTfWS...
# data {'artist_followers': 7939586, 'artist_popularity': 80, 'album_type': 'album', 'label': 'LVRN/Interscope Records'}
# Fetching 07dtD7iciEL7vHqATMXg3V...
# data {'artist_followers': 2368552, 'artist_popularity': 69, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 6Fqdip4cWZEFwtmdhX9iNq...
# data {'artist_followers': 1267525, 'artist_popularity': 67, 'album_type': 'album', 'label': 'Epitaph'}
# Fetching 5BInskLvwqz56ClUpfqdI4...
# data {'artist_followers': 1211589, 'artist_popularity': 61, 'album_type': 'album', 'label': 'F.O.F. Entertainment'}
# Fetching 12v5GBM74fB8WsHJPQRTIe...
# data {'artist_followers': 723515, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Flying Buddha/Sony Masterworks'}
# Fetching 63Ly2sEzloc9s0yAXlMi6r...
# data {'artist_followers': 1078658, 'artist_popularity': 60, 'album_type': 'single', 'label': 'Good Years Recordings Limited'}
# Fetching 7FkyQsWH9mmxoYLCNj4f8y...
# data {'artist_followers': 1108313, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Geffen'}
# Fetching 3uxhyRdWVXp7GQvERQl6fA...
# data {'artist_followers': 13551592, 'artist_popularity': 89, 'album_type': 'album', 'label': 'XL Recordings'}
# Fetching 6RV5LttaFB7WOLme0qUlJs...
# data {'artist_followers': 4515259, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Atlantic Records'}
# Fetching 4ydfntQQR5g5gkACYwXHHt...
# data {'artist_followers': 575006, 'artist_popularity': 51, 'album_type': 'single', 'label': 'Loveway Records'}
# Fetching 5MUWpxHzlG5M5N2C0T7qs9...
# data {'artist_followers': 819522, 'artist_popularity': 60, 'album_type': 'album', 'label': 'Saba Pivot, LLC'}
# Fetching 0i6c86ntKJoZpKk8aCHL3c...
# data {'artist_followers': 647859, 'artist_popularity': 57, 'album_type': 'single', 'label': 'Beatnik Creative'}
# Progress saved at row 6690
# Fetching 6C0xucNj75wRdlejwWIEW1...
# data {'artist_followers': 1865579, 'artist_popularity': 64, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 43TQVltxEHaqCKpSsttaT5...
# data {'artist_followers': 2921616, 'artist_popularity': 72, 'album_type': 'album', 'label': 'Atlantic Records/ATG'}
# Fetching 3fPSHjVO4iwwGEhHvTwlNb...
# data {'artist_followers': 1330376, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Atlantic Records'}
# Fetching 4i76vmvahz5a4MhinU59sI...
# data {'artist_followers': 7792694, 'artist_popularity': 82, 'album_type': 'album', 'label': 'Roadrunner Records'}
# Fetching 0jm6UoOxeX1rtYKLrG7pnj...
# data {'artist_followers': 122793, 'artist_popularity': 51, 'album_type': 'album', 'label': 'Word Records'}
# Fetching 7ARLbcqLgOrBI2JfzfKtHD...
# data {'artist_followers': 159293, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Atlantic/Photo Finish Records'}
# Fetching 7fzyYXzeWLuaHpgMR9pmsx...
# data {'artist_followers': 1010692, 'artist_popularity': 66, 'album_type': 'album', 'label': 'High Top Mountain Records'}
# Progress saved at row 6730
# Fetching 3BLqtquZ8MaG4sJsru9q8m...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 4oFyfXZgrirMQCwjhXGnj6...
# data {'artist_followers': 213064, 'artist_popularity': 58, 'album_type': 'album', 'label': 'Lowly'}
# Fetching 3SwhPTNNU5hpF33bbCsji6...
# data {'artist_followers': 462701, 'artist_popularity': 62, 'album_type': 'single', 'label': 'Motown'}
# Fetching 4oI2qtjY1QHJ7NpYuid5KB...
# data {'artist_followers': 6174365, 'artist_popularity': 78, 'album_type': 'album', 'label': 'Virgin Records'}
# Fetching 3GbvAuf1qB1XxwnNoRcAFy...
# data {'artist_followers': 1221999, 'artist_popularity': 63, 'album_type': 'album', 'label': 'Sub Pop Records'}
# Fetching 0i4nHa7wLCX11M7yIp7iTJ...
# data {'artist_followers': 291676, 'artist_popularity': 56, 'album_type': 'album', 'label': 'Hopeless Records'}
# Fetching 0loXYu3N98L7vy2lNbYm2t...
# data {'artist_followers': 2539400, 'artist_popularity': 70, 'album_type': 'album', 'label': 'Glassnote Entertainment Group LLC'}
# Fetching 2lWAP3l4ILsjy11jsX49Ys...
# data {'artist_followers': 1509659, 'artist_popularity': 70, 'album_type': 'album', 'label': 'Forefront (FRF)'}
# Fetching 5XzokqsAmkv0cjk1kAUwiM...
# data {'artist_followers': 711506, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Puscifer Entertainment'}
# Fetching 3DgNj1aYbSRVoVO8yX7DRt...
# data {'artist_followers': 1708367, 'artist_popularity': 68, 'album_type': 'album', 'label': 'Interscope'}
# Progress saved at row 6740
# Fetching 3If9Idk1rglOqubIsJcpmv...
# data {'artist_followers': 4549502, 'artist_popularity': 77, 'album_type': 'album', 'label': 'DGC'}
# Progress saved at row 6840
# Fetching 4Vha0YyxRZSfLzzoph7rNx...
# data {'artist_followers': 1270813, 'artist_popularity': 58, 'album_type': 'album', 'label': 'OVO Sound/Warner Records'}
# Fetching 2rHTaoTAccp54yHzmqgOkY...
# data {'artist_followers': 492805, 'artist_popularity': 53, 'album_type': 'album', 'label': 'Geffen'}
# Fetching 0aAnHzjVQxXyvmbOHGAsfD...
# data {'artist_followers': 114008, 'artist_popularity': 40, 'album_type': 'album', 'label': 'Ino/Columbia'}
# Fetching 6qYTL4IxHaHTfum39X62tr...
# data {'artist_followers': 5825427, 'artist_popularity': 78, 'album_type': 'album', 'label': 'Atlantic Records'}
# Fetching 79XKPlY5fagGd2iXhDPrEs...
# data {'artist_followers': 121312, 'artist_popularity': 49, 'album_type': 'single', 'label': 'Mutant League Records'}
# Fetching 0X0fvHVXgFX8413g1dcn6Y...
# data {'artist_followers': 11651919, 'artist_popularity': 80, 'album_type': 'album', 'label': 'Hopeless Records'}
# Fetching 06isZAG9Bgm4jhPj7V0Rhx...
# data {'artist_followers': 4549502, 'artist_popularity': 77, 'album_type': 'album', 'label': 'DGC'}
# Progress saved at row 6880
# Fetching 7e8KTrlIt6SeImB3vM98ZF...
# data {'artist_followers': 1010692, 'artist_popularity': 66, 'album_type': 'album', 'label': 'High Top Mountain Records'}
# Fetching 5mqEL5pgnDCcWtTWpAofIV...
# data {'artist_followers': 480626, 'artist_popularity': 54, 'album_type': 'album', 'label': 'RCA Records Label'}
# Fetching 3nM1EJJ80pJGiG32WFfJxc...
# data {'artist_followers': 1577340, 'artist_popularity': 75, 'album_type': 'album', 'label': 'The End Records'}
# Fetching 01UstUPbzPgq2MNp6h0tVo...
# data {'artist_followers': 13551592, 'artist_popularity': 89, 'album_type': 'album', 'label': 'XL Recordings'}
# Fetching 0Uxmhbm1sUiyh6geMnwzG4...
# data {'artist_followers': 632651, 'artist_popularity': 56, 'album_type': 'single', 'label': 'Dixon Court Records'}
# Fetching 3fDV1GHwjDNhWEMDKupa9Q...
# data {'artist_followers': 11651919, 'artist_popularity': 80, 'album_type': 'single', 'label': 'Warner Records'}
# Fetching 1AO273oogzWXHmXckUHipk...
# data {'artist_followers': 2539400, 'artist_popularity': 70, 'album_type': 'album', 'label': 'Glassnote Entertainment Group LLC'}
# Fetching 5BqW7B2eS98AlUAwW7EFLp...
# data {'artist_followers': 514110, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Motown'}
# Fetching 1lAFWiaVhJhvQ5Gtzp6vSu...
# data {'artist_followers': 5168693, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Universal Music Mexico'}
# Fetching 7ItpUlCUwTRyiXZ0YclPQ7...
# data {'artist_followers': 124943, 'artist_popularity': 47, 'album_type': 'album', 'label': 'Because Music'}
# Progress saved at row 6890
# Fetching 1F0tYkzGNjogSmx49DiaBa...
# data {'artist_followers': 262879, 'artist_popularity': 53, 'album_type': 'single', 'label': 'Keep it on the Lolo'}
# Fetching 76BYv24CcZt2u94JRjmATX...
# data {'artist_followers': 1861282, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Island Records'}
# Fetching 2TTmk2xlPcdzQnrTHJQP8G...
# data {'artist_followers': 1755400, 'artist_popularity': 70, 'album_type': 'album', 'label': 'Rhino/Elektra'}
# Fetching 69ZRVsGoLXjHrQWHMX5iCN...
# data {'artist_followers': 7599668, 'artist_popularity': 78, 'album_type': 'album', 'label': 'Reprise'}
# Fetching 2vfshZvISOKy2Je7wQBWOV...
# data {'artist_followers': 31443678, 'artist_popularity': 92, 'album_type': 'album', 'label': 'Warner Records'}
# Fetching 7jeI6EdY0elPSNz80mAKS8...
# data {'artist_followers': 31443678, 'artist_popularity': 92, 'album_type': 'album', 'label': 'Warner Records'}
# Progress saved at row 6930
# Fetching 5Q6Xzp25aXYxNJ4B6vBkcf...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 26zKr68t6Qu4D2bsehaCbt...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 66XZpAHmX4f4ce88KaDb5o...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 3Lchk4Sg2rsZftO5LpDZwX...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 626LxCs5QsDjY78TF8mS4y...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 7rT2HkehkqoRVZ5Qjoz40C...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 4zmPuY0gesuPRL1uoubWvz...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 5JRjB5UYBx04qgfWVbY6ZY...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 1FUiPIRS9mQugZ7omGeHf9...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Progress saved at row 7070
# Fetching 2JKPDzbXrFT3rCFcUtVzoT...
# data {'artist_followers': 956524, 'artist_popularity': 61, 'album_type': 'compilation', 'label': 'Geffen*'}
# Fetching 193a05k1nFx9JOumDLUUJR...
# data {'artist_followers': 106833, 'artist_popularity': 33, 'album_type': 'album', 'label': 'Blaster Records'}
# Fetching 46xQg7YIaI67ehFRkPjV5g...
# data {'artist_followers': 637957, 'artist_popularity': 53, 'album_type': 'album', 'label': 'RCA Records Label Nashville'}
# Fetching 5hot2LA4VKND8CwnvLw2uu...
# data {'artist_followers': 2709981, 'artist_popularity': 68, 'album_type': 'album', 'label': 'MCA Nashville'}
# Fetching 2WL8MVwpWCV0OHsd1mzxPn...
# data {'artist_followers': 2718726, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Show Dog Universal Music'}
# Fetching 0E0DE2QX5Q3kg39jdkVeDN...
# data {'artist_followers': 6007146, 'artist_popularity': 83, 'album_type': 'album', 'label': 'Bad Apple Inc.'}
# Fetching 2KGrxtX5Wu1AMRv5CTDE2F...
# data {'artist_followers': 1062818, 'artist_popularity': 59, 'album_type': 'compilation', 'label': 'Universal/Island Def Jam'}
# Fetching 2VBLgWNbhskMSG4VR1VUxv...
# data {'artist_followers': 1728823, 'artist_popularity': 72, 'album_type': 'single', 'label': 'RCA Records Label Nashville'}
# Fetching 0XZqDws4aiAVYQ0qc7G6b4...
# data {'artist_followers': 3666881, 'artist_popularity': 72, 'album_type': 'compilation', 'label': 'Lyric Street'}
# Fetching 0DvT7TPU064IISWscKzEuV...
# data {'artist_followers': 144197, 'artist_popularity': 54, 'album_type': 'album', 'label': 'BackRoad Records/ Average Joes Entertainment'}
# Progress saved at row 7080
# Fetching 5Sxz7cjDvezdZgjx3aZNvz...
# data {'artist_followers': 282684, 'artist_popularity': 53, 'album_type': 'compilation', 'label': 'Universal Strategic Marketing'}
# Fetching 7b6S83HsceeUVpu28mWyF5...
# data {'artist_followers': 72194, 'artist_popularity': 49, 'album_type': 'album', 'label': 'Rock & Soul'}
# Fetching 30OYvco4YZRz3wF2SP2VZC...
# data {'artist_followers': 424600, 'artist_popularity': 60, 'album_type': 'compilation', 'label': 'Rhino/Warner Records'}
# Fetching 1cw56cVdCdggeggTmHOeKh...
# data {'artist_followers': 148840, 'artist_popularity': 46, 'album_type': 'single', 'label': 'Cryptic Wisdom'}
# Fetching 2oz8dQ8sZcEigXMSYcFnKb...
# data {'artist_followers': 2718726, 'artist_popularity': 64, 'album_type': 'compilation', 'label': 'Capitol Nashville'}
# Fetching 4VJrOafjM19NgIB4oujV6r...
# data {'artist_followers': 601725, 'artist_popularity': 63, 'album_type': 'compilation', 'label': 'RCA/Legacy'}
# Fetching 0u6lb5FT7FHmLCCeGvMCFy...
# data {'artist_followers': 438122, 'artist_popularity': 55, 'album_type': 'album', 'label': 'Gusto Records'}
# Fetching 2tocd0e0UQUU8TgQGQ0BPy...
# data {'artist_followers': 170680, 'artist_popularity': 51, 'album_type': 'single', 'label': 'Highway 65'}
# Fetching 2CFtB64mDu2XCFjvGJhc9k...
# data {'artist_followers': 217024, 'artist_popularity': 49, 'album_type': 'album', 'label': 'A&M'}
# Fetching 40mEN7urf2sUM0oAdIlzLw...
# data {'artist_followers': 148941, 'artist_popularity': 40, 'album_type': 'album', 'label': 'Psychopathic'}
# Progress saved at row 7220
# Fetching 0aUu1CO88d2kiXOGrImtbH...
# data {'artist_followers': 857064, 'artist_popularity': 62, 'album_type': 'album', 'label': 'Red Bow Records'}
# Fetching 1k3TEMaIeM0U80lxWe6UjK...
# data {'artist_followers': 2878247, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Capitol Records Nashville'}
# Fetching 4pUJx5vc2IE60TMB6Hqerv...
# data {'artist_followers': 853817, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Mercury Nashville'}
# Fetching 5PjpIjrejmldJosUT8ARfC...
# data {'artist_followers': 2709981, 'artist_popularity': 68, 'album_type': 'album', 'label': 'MCA Nashville'}
# Fetching 0VTQQh0dXlKRGsglMG28Us...
# data {'artist_followers': 445273, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Rhino/Elektra'}
# Fetching 6tBnLpw8NNAIgOthHyLgHv...
# data {'artist_followers': 494050, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Warner Records'}
# Fetching 2yo6fQ4nsx30m9MJb5TFFw...
# data {'artist_followers': 96872, 'artist_popularity': 54, 'album_type': 'single', 'label': '287 Records'}
# Fetching 32hhmY2qPNo8IfA5KYG49R...
# data {'artist_followers': 238254, 'artist_popularity': 51, 'album_type': 'single', 'label': 'Dylan Schneider'}
# Fetching 1kbPUVu865ZKXvf5nMnLnJ...
# data {'artist_followers': 2023893, 'artist_popularity': 70, 'album_type': 'compilation', 'label': 'Warner Records'}
# Fetching 3JFnDfXJtwKoh1Ub0KHMpi...
# data {'artist_followers': 841772, 'artist_popularity': 59, 'album_type': 'compilation', 'label': 'MCA Nashville'}
# Fetching 4Rjqeagb3KQcVm0WLeb2du...
# data {'artist_followers': 5111336, 'artist_popularity': 76, 'album_type': 'album', 'label': 'MCA Nashville'}
# Fetching 7pU7RegippbKcVJUj7ybiS...
# data {'artist_followers': 623133, 'artist_popularity': 61, 'album_type': 'album', 'label': 'Angels & Outlaws'}
# Fetching 2LoOZz03VM2dLvR7q4qQ7J...
# data {'artist_followers': 3312583, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Arista Nashville'}
# Fetching 2Skl19UgxVO85BH3cTKip6...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 3o5IChTvWMLHXkmnlSYI5z...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 0lwnqINENtZoQsH0bOl7gO...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 0BtqwFxTqPoMIRNq6Og77I...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 0KGWGfFDNoVVGOPvoFZw6w...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Progress saved at row 7370
# Fetching 6CxGj7BiBQExZ22T2Ov5zm...
# data {'artist_followers': None, 'artist_popularity': None, 'album_type': None, 'label': None}
# Fetching 4rQfCllOKfgfsZdwvRUT8G...
# data {'artist_followers': 1126279, 'artist_popularity': 72, 'album_type': 'album', 'label': 'Wiggy Thump Records'}
# Fetching 0oqgzsqQoeTn5JMAhIHmXl...
# data {'artist_followers': 325323, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Atlantic/Warner Music Nashville'}
# Fetching 4flY2h5RvscPup3rzlUzwe...
# data {'artist_followers': 142792, 'artist_popularity': 42, 'album_type': 'compilation', 'label': 'Gusto Records'}
# Fetching 4AmLQCEHTDKrhxgyMGD2N9...
# data {'artist_followers': 1890003, 'artist_popularity': 71, 'album_type': 'album', 'label': 'Special Products'}
# Fetching 309SA0F7NDoFhiEWbFAXiU...
# data {'artist_followers': 5111336, 'artist_popularity': 76, 'album_type': 'album', 'label': 'MCA Nashville'}
# Fetching 6b45yra2a9So8yTNeHZdgt...
# data {'artist_followers': 400051, 'artist_popularity': 57, 'album_type': 'album', 'label': '3 Legged Records'}
# Fetching 2M5HmGMNoPQetbAc3BnETK...
# data {'artist_followers': 857064, 'artist_popularity': 62, 'album_type': 'album', 'label': 'Show Dog Universal Music'}
# Fetching 4nn9YiQFfP87C0Qab2Jlbb...
# data {'artist_followers': 5019509, 'artist_popularity': 74, 'album_type': 'album', 'label': 'Big Machine Records, LLC'}
# Progress saved at row 7430
# Fetching 23AyMXVsACU30I5QJaBt9t...
# data {'artist_followers': 96452, 'artist_popularity': 42, 'album_type': 'single', 'label': 'New Kid On The Block Entertainment, LLC'}
# Fetching 5r33RyATd6nmLDsDul4yuQ...
# data {'artist_followers': 201092, 'artist_popularity': 56, 'album_type': 'album', 'label': 'Average Joes Entertainment'}
# Fetching 0b9rOqo0DaBgB807XzQ2sG...
# data {'artist_followers': 23212, 'artist_popularity': 42, 'album_type': 'single', 'label': 'SP Music/Non Delux'}
# Fetching 2JdLYKj6k9Ksl6TuVJcN3V...
# data {'artist_followers': 3312583, 'artist_popularity': 75, 'album_type': 'compilation', 'label': 'Arista Nashville'}
# Fetching 1fmuowoQBIIthGEokf4I9l...
# data {'artist_followers': 7489908, 'artist_popularity': 73, 'album_type': 'album', 'label': 'Warner Records'}
# Fetching 7gNbidsHK16wvnuK2VgaVc...
# data {'artist_followers': 2948945, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Iconic Artists Group'}
# Fetching 4WiMhArdb8BD7KKkin1g8h...
# data {'artist_followers': 726508, 'artist_popularity': 66, 'album_type': 'album', 'label': 'Lauren Alaina'}
# Progress saved at row 7470
# Fetching 15ILv1t2MnijZHzwyLF7Dj...
# data {'artist_followers': 1010692, 'artist_popularity': 66, 'album_type': 'album', 'label': 'High Top Mountain Records'}
# Fetching 2Nar74mf8qESr15kGYcPCD...
# data {'artist_followers': 588601, 'artist_popularity': 65, 'album_type': 'compilation', 'label': 'Warner Music Group - X5 Music Group'}
# Fetching 3BjcPLwNT6WpjuUlR7vx5z...
# data {'artist_followers': 273970, 'artist_popularity': 55, 'album_type': 'single', 'label': 'Stoney Creek Records'}
# Fetching 4i1l0cGAAoGTPmFNNUs4aZ...
# data {'artist_followers': 273970, 'artist_popularity': 55, 'album_type': 'album', 'label': 'Stoney Creek Records'}
# Fetching 4vJTsPU2BqOCd6rQ6XrJIr...
# data {'artist_followers': 183148, 'artist_popularity': 48, 'album_type': 'single', 'label': 'Quantum Spirit Records'}
# Fetching 7caSLni4sI8AJ2oVmz7n0w...
# data {'artist_followers': 36273, 'artist_popularity': 36, 'album_type': 'single', 'label': 'Creative Nation Records'}
# Fetching 2kFE6U1V5TZ9kC5AvrR1L5...
# data {'artist_followers': 110052, 'artist_popularity': 51, 'album_type': 'single', 'label': 'Elektra Nashville'}
# Fetching 6iYIdaolmbPVqKPxcspOIs...
# data {'artist_followers': 884576, 'artist_popularity': 72, 'album_type': 'single', 'label': 'Columbia Nashville'}
# Fetching 1xinrSXajiIVeaAEwrGPob...
# data {'artist_followers': 110052, 'artist_popularity': 51, 'album_type': 'single', 'label': 'Big Smo Inc.'}
# Fetching 3Y6pEkkbK1gdrzg51OMfM4...
# data {'artist_followers': 978288, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Mercury Nashville'}
# Progress saved at row 7480
# Fetching 40PpMzWwqCG1TxMy2qpda3...
# data {'artist_followers': 4127037, 'artist_popularity': 76, 'album_type': 'album', 'label': 'Capitol Nashville'}
# Fetching 2ZJTiN2hJBOxF6MRFkAWKH...
# data {'artist_followers': 413370, 'artist_popularity': 56, 'album_type': 'album', 'label': 'D. Thrash Productions'}
# Fetching 2PnaLj5nlDAm6uBd5YGDpK...
# data {'artist_followers': 897793, 'artist_popularity': 51, 'album_type': 'album', 'label': 'Capitol Nashville'}
# Fetching 2fnAWGcjkl6TXbq58WjCJv...
# data {'artist_followers': 5842653, 'artist_popularity': 77, 'album_type': 'album', 'label': 'Geffen*'}
# Fetching 496ZqzTh1iaITS5D1IjlPX...
# data {'artist_followers': 4135941, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Southern Ground/Atlantic'}
# Fetching 1Ym1iazLFj6sysHoAX6Px3...
# ...
# Fetching 0fM5MtNJg3l7iGnOrxMoMB...
# data {'artist_followers': 884576, 'artist_popularity': 72, 'album_type': 'single', 'label': 'Columbia Nashville'}
# Fetching 4F2JyLPNoCIUshjktmHxCN...
# data {'artist_followers': 217613, 'artist_popularity': 54, 'album_type': 'compilation', 'label': 'Varese Sarabande'}
# Fetching 2VFF3rDyYMcPZEMNcZ4AmU...
# data {'artist_followers': 1912463, 'artist_popularity': 64, 'album_type': 'album', 'label': 'The Valory Music Co., LLC'}
# Fetching 2yDltDae65sVOkn1a0zp1D...
# data {'artist_followers': 272843, 'artist_popularity': 52, 'album_type': 'album', 'label': 'BIG Label Records'}
# Fetching 6xN5xsIl2cR1pOjnzShHAN...
# data {'artist_followers': 1186016, 'artist_popularity': 62, 'album_type': 'album', 'label': 'RCA Records Label Nashville'}
# Fetching 5qAIGEwejruJoQ9eniyunG...
# data {'artist_followers': 257205, 'artist_popularity': 40, 'album_type': 'single', 'label': 'Emblem / Warner Records Nashville/ Reprise'}
# Fetching 5xNI0lNPYmHfKGM0Qyaya2...
# data {'artist_followers': 1349687, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Vanguard'}
# Progress saved at row 8080
# Fetching 135JJbGDIkHe8V6c2YExiL...
# data {'artist_followers': 2984088, 'artist_popularity': 74, 'album_type': 'album', 'label': 'Show Dog Nashville'}
# Fetching 2Tm7nXWJouomHeRN9bT6IK...
# data {'artist_followers': 69389, 'artist_popularity': 47, 'album_type': 'album', 'label': 'CN Records'}
# Fetching 0s7j6vOpvCJH5dsotfAfPX...
# data {'artist_followers': 37180, 'artist_popularity': 34, 'album_type': 'album', 'label': 'New West Records'}
# Fetching 7ukja8GBVUlcdqXpNnaCcj...
# data {'artist_followers': 853817, 'artist_popularity': 64, 'album_type': 'compilation', 'label': 'Show Dog Universal Music'}
# Fetching 69BhgVzGUe3V4QMFekmttL...
# data {'artist_followers': 363096, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Acoustic Disc'}
# Fetching 1QrS4fwVbEERAKzr2QiKNg...
# data {'artist_followers': 321616, 'artist_popularity': 43, 'album_type': 'album', 'label': 'RCA Records Label Nashville'}
# Fetching 474LmuGobZYieL7Juo9d8G...
# data {'artist_followers': 1890003, 'artist_popularity': 71, 'album_type': 'compilation', 'label': 'Curb Records'}
# Fetching 2aRZlcf5SE7Qq0SslQh30R...
# data {'artist_followers': 486461, 'artist_popularity': 60, 'album_type': 'album', 'label': 'RLG/Legacy'}
# Fetching 4pZJvBhOYkiSYrrSk6MZOn...
# data {'artist_followers': 131650, 'artist_popularity': 46, 'album_type': 'album', 'label': 'New Rounder'}
# Fetching 2NBGNKapS05nmPalkrL2Df...
# data {'artist_followers': 246439, 'artist_popularity': 43, 'album_type': 'single', 'label': 'Stroudavarious'}
# Progress saved at row 8090
# Fetching 7b8mI7YNGUfckTtyzoe1Zm...
# data {'artist_followers': 3364935, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Mercury Nashville'}
# Fetching 3FfxN6oyZfYV4osU6PlhJZ...
# data {'artist_followers': 884576, 'artist_popularity': 72, 'album_type': 'single', 'label': 'Columbia Nashville'}
# Fetching 5WOGXAX9WJBiLCYcsy0HD9...
# data {'artist_followers': 55174, 'artist_popularity': 50, 'album_type': 'album', 'label': 'Filmore'}
# Fetching 7u481CObcaiF6AaLPjtY9W...
# data {'artist_followers': 3335568, 'artist_popularity': 76, 'album_type': 'album', 'label': 'Arista Nashville'}
# Fetching 2O5uZTtEzTLoDondwa0L6y...
# data {'artist_followers': 2175, 'artist_popularity': 15, 'album_type': 'single', 'label': 'Corey Cox'}
# Fetching 2GyTrOs3AEAjy4MhV4a0kZ...
# data {'artist_followers': 237307, 'artist_popularity': 55, 'album_type': 'album', 'label': 'Capitol Records'}
# Fetching 3wDCmcQme2hrvYihP6fI3L...
# data {'artist_followers': 1116456, 'artist_popularity': 62, 'album_type': 'album', 'label': 'MCA Nashville'}
# Fetching 2aOuI7RTbF17mEdAHbDlhI...
# data {'artist_followers': 1215567, 'artist_popularity': 57, 'album_type': 'album', 'label': 'Atlantic Nashville'}
# Fetching 05mzctclS0ZqqTLEiDIGkt...
# data {'artist_followers': 1116503, 'artist_popularity': 61, 'album_type': 'album', 'label': 'EMI'}
# Fetching 7GUSroVy3kBqWXLLDT9qtI...
# data {'artist_followers': 1492171, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Atlantic Nashville'}
# Progress saved at row 8100
# Fetching 5lCmk4gsdCNTkrosL4gogj...
# data {'artist_followers': 338225, 'artist_popularity': 45, 'album_type': 'album', 'label': 'Mercury Nashville'}
# Fetching 4eXtm78zEI4Cu3mWpVzH5V...
# data {'artist_followers': 292496, 'artist_popularity': 52, 'album_type': 'compilation', 'label': 'Arista Nashville'}
# Fetching 1NUVC9w3ckWfeS3XVqzb0p...
# data {'artist_followers': 4127037, 'artist_popularity': 76, 'album_type': 'album', 'label': 'Capitol Nashville'}
# Fetching 2Bk0eoq8bN02TbqMlCLOHz...
# data {'artist_followers': 446675, 'artist_popularity': 52, 'album_type': 'album', 'label': 'Wheelhouse Records'}
# Fetching 4XoYeolVYTiddO9wZLXLgl...
# data {'artist_followers': 363096, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Round Records'}
# Fetching 29j7cM4nqk8plXoSUPmbt6...
# data {'artist_followers': 915900, 'artist_popularity': 61, 'album_type': 'compilation', 'label': 'Epic/Legacy'}
# Fetching 3w6VIMJd83dPA22ddLasQj...
# data {'artist_followers': 5111336, 'artist_popularity': 76, 'album_type': 'album', 'label': 'MCA Nashville'}
# Progress saved at row 8140
# Fetching 5u3WokNXe0Ro2nhnYRHyLL...
# data {'artist_followers': 7489908, 'artist_popularity': 73, 'album_type': 'single', 'label': 'Warner Records/Nashville'}
# Fetching 1X6Q0pEHOKycY661hm7yIY...
# data {'artist_followers': 544947, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Big Machine Records, LLC'}
# Fetching 58SvNnFnHLWJRTz2bkng86...
# data {'artist_followers': 856238, 'artist_popularity': 60, 'album_type': 'album', 'label': 'Virgin'}
# Fetching 3ZifXUzaVPcffT9uIcjHEh...
# data {'artist_followers': 2892282, 'artist_popularity': 68, 'album_type': 'album', 'label': 'Arista Nashville'}
# Fetching 0WURWkm74oCb2orvSFSruK...
# data {'artist_followers': 980786, 'artist_popularity': 62, 'album_type': 'album', 'label': 'Columbia'}
# Fetching 4Xcf7CxAyFXsFMNp77WHkT...
# data {'artist_followers': 47076, 'artist_popularity': 32, 'album_type': 'album', 'label': 'Acony Records'}
# Fetching 0ZRCBySkFaUDdASTRzQxtr...
# data {'artist_followers': 517243, 'artist_popularity': 52, 'album_type': 'album', 'label': 'Atlantic Records'}
# Fetching 6Y2QWiL3v8DlsX8tHtQhpR...
# data {'artist_followers': 2757868, 'artist_popularity': 70, 'album_type': 'album', 'label': 'Capitol Records Nashville'}
# Fetching 5JZQNAaDhXrKkTwt6hCIGI...
# data {'artist_followers': 1995458, 'artist_popularity': 65, 'album_type': 'album', 'label': 'RCA Records Label Nashville'}
# Fetching 0EDIRMxCC8ByrL1Tk0LP7H...
# data {'artist_followers': 104692, 'artist_popularity': 43, 'album_type': 'album', 'label': 'New West Records'}
# Progress saved at row 8150
# Fetching 4zdlsu8oRItjR5GIsgcDcl...
# data {'artist_followers': 6007146, 'artist_popularity': 83, 'album_type': 'album', 'label': 'Jellyroll & Struggle Jennings'}
# Fetching 6otMdQUdrKjxV5PtVTd4vq...
# data {'artist_followers': 79869, 'artist_popularity': 41, 'album_type': 'album', 'label': 'Outpost'}
# Fetching 2zESgCpILGWNclCKeCYAO3...
# data {'artist_followers': 115183, 'artist_popularity': 53, 'album_type': 'album', 'label': 'Bill Grease Records LLC'}
# Fetching 6SIG354qGOB0BXAMXDeMmu...
# data {'artist_followers': 413370, 'artist_popularity': 56, 'album_type': 'album', 'label': 'D. Thrash productions'}
# Fetching 3qh7eMvXXKWy7p9Nca3qoZ...
# data {'artist_followers': 1995458, 'artist_popularity': 65, 'album_type': 'album', 'label': 'RCA Records Label Nashville'}
# Fetching 7HxBnhvMjQHaOMtzpdRmjm...
# data {'artist_followers': 37180, 'artist_popularity': 34, 'album_type': 'album', 'label': 'New West Records'}
# Fetching 42Lryt8OjQ3C86dZAOgUdd...
# data {'artist_followers': 580603, 'artist_popularity': 54, 'album_type': 'album', 'label': 'Strange Music, Inc'}
# Progress saved at row 8190
# Fetching 55kWN35yw1rjuTRDK46lS6...
# data {'artist_followers': 155532, 'artist_popularity': 51, 'album_type': 'album', 'label': 'BOTTLENECK MUSIC'}
# Fetching 5fCxzWbeRJgqvKhOGwO8my...
# data {'artist_followers': 274684, 'artist_popularity': 55, 'album_type': 'album', 'label': 'Southeastern Records'}
# Fetching 6qCizyY56lbF9xkANNEOt3...
# data {'artist_followers': 2878247, 'artist_popularity': 64, 'album_type': 'compilation', 'label': 'Capitol Nashville'}
# Fetching 0VGrPvqwE7sKBoxNjAevCV...
# data {'artist_followers': 30479, 'artist_popularity': 42, 'album_type': 'single', 'label': 'Tape Room Records'}
# Fetching 2grwz4trMgDLOfEITQgAv3...
# data {'artist_followers': 1413841, 'artist_popularity': 58, 'album_type': 'compilation', 'label': 'RLG/Legacy'}
# Fetching 0ySxC028CNDtK2G7zuaUcn...
# data {'artist_followers': 1017329, 'artist_popularity': 62, 'album_type': 'album', 'label': 'RRE, LLC / Republic'}
# Fetching 7szyzZ3J9ortisMHATOXCp...
# data {'artist_followers': 2948945, 'artist_popularity': 75, 'album_type': 'album', 'label': 'RCA Records Label Nashville'}
# Fetching 6lMNJzDA47MaCZjjKgam5N...
# data {'artist_followers': 245311, 'artist_popularity': 51, 'album_type': 'album', 'label': 'Columbia Nashville'}
# Fetching 15ebbIRQk7LfUQDPtYBesA...
# data {'artist_followers': 446675, 'artist_popularity': 52, 'album_type': 'album', 'label': 'Pioneer Music'}
# Fetching 7Ebjql20F9A7Xtqz0tmScF...
# data {'artist_followers': 88604, 'artist_popularity': 53, 'album_type': 'album', 'label': 'Capitol Nashville'}
# Progress saved at row 8200
# Fetching 3oXK0zDFU4rxciSiMGhlQF...
# data {'artist_followers': 446675, 'artist_popularity': 52, 'album_type': 'single', 'label': 'Wheelhouse Records'}
# Fetching 4wPYJn1VrN6M6HXyBIOAbc...
# data {'artist_followers': 495124, 'artist_popularity': 53, 'album_type': 'compilation', 'label': 'Rhino/Warner Records'}
# Fetching 1TpSpbjQ6tgFiqo5yGo31U...
# data {'artist_followers': 1246809, 'artist_popularity': 62, 'album_type': 'single', 'label': 'Artist Revolution'}
# Fetching 7vUnJYVu4Dzb15695KLGvy...
# data {'artist_followers': 77966, 'artist_popularity': 39, 'album_type': 'single', 'label': '653157 Records DK'}
# Fetching 1BxqzBVeusLt00wy6Q0AUb...
# data {'artist_followers': 1890003, 'artist_popularity': 71, 'album_type': 'album', 'label': 'Curb Records'}
# Fetching 17JauV7NyUrllejgZRYrlt...
# data {'artist_followers': 274684, 'artist_popularity': 55, 'album_type': 'album', 'label': 'Lightning Rod Records'}
# Fetching 07W5A4MpsFP6mT0BSwoNPG...
# data {'artist_followers': 44685, 'artist_popularity': 40, 'album_type': 'single', 'label': 'Big Yellow Dog Music/RLM Nashville'}
# Progress saved at row 8240
# Fetching 6siLdqp6KPxENMYRlz32wd...
# data {'artist_followers': 1155303, 'artist_popularity': 61, 'album_type': 'single', 'label': 'Average Joes Entertainment'}
# Fetching 0QCwbcQegRzVSnybXCA6cZ...
# data {'artist_followers': 88214, 'artist_popularity': 38, 'album_type': 'album', 'label': 'Legacy Recordings'}
# Fetching 2A37LfklNSjfrWId0NWa0q...
# data {'artist_followers': 853817, 'artist_popularity': 64, 'album_type': 'album', 'label': 'BNA Records Label'}
# Fetching 782xYvDYZkCBz7Gn5gqbxf...
# data {'artist_followers': 1286164, 'artist_popularity': 65, 'album_type': 'album', 'label': 'Lawrence Music Group'}
# Fetching 3aNjDDUoHGcIjZKTiZmbFJ...
# data {'artist_followers': 75823, 'artist_popularity': 48, 'album_type': 'single', 'label': '604 Records'}
# Fetching 1yexhSDARSLVvRCBU3wDAm...
# data {'artist_followers': 1074283, 'artist_popularity': 56, 'album_type': 'album', 'label': 'Columbia/Legacy'}
# Fetching 2DI1SvvgzhIybzuM0AjyvR...
# data {'artist_followers': 614659, 'artist_popularity': 58, 'album_type': 'compilation', 'label': 'Average Joes Entertainment'}
# Fetching 6j7MXYyyMQXHStKzBFAUez...
# data {'artist_followers': 391327, 'artist_popularity': 54, 'album_type': 'single', 'label': 'MCA Nashville'}
# Fetching 0IQ0qn8a2TN9Tmo7p5KmUs...
# data {'artist_followers': 2948945, 'artist_popularity': 75, 'album_type': 'album', 'label': 'Columbia Nashville'}
# Fetching 3jvrHHVSoWCZqGNSnfplb5...
# data {'artist_followers': 9372250, 'artist_popularity': 78, 'album_type': 'album', 'label': 'Capitol Nashville'}
# Progress saved at row 8250
# Fetching 360iblLqhydYEtT2vKWGIG...
# data {'artist_followers': 42145, 'artist_popularity': 33, 'album_type': 'album', 'label': 'Virgin Records'}
# Fetching 6cwS1ZesJr5sxCkVTrydLR...
# data {'artist_followers': 5111336, 'artist_popularity': 76, 'album_type': 'album', 'label': 'MCA Nashville'}
# Fetching 318AgoKVYc1BuX8XBthGtR...
# data {'artist_followers': 1536902, 'artist_popularity': 69, 'album_type': 'album', 'label': 'Monument'}
# Fetching 2cwGK6ZYfiZ1EZva2VEKSN...
# data {'artist_followers': 152071, 'artist_popularity': 44, 'album_type': 'compilation', 'label': 'Columbia Nashville Legacy'}
# Fetching 6XJ9H7LxgRjxvkBD9iS9G1...
# data {'artist_followers': 2892282, 'artist_popularity': 68, 'album_type': 'album', 'label': 'Arista Nashville'}
# Fetching 1kuf58pPX4pLciPhLhIlfT...
# data {'artist_followers': 472006, 'artist_popularity': 46, 'album_type': 'album', 'label': 'Merge Entertainment'}
# Fetching 41vSqn8lbTtooJiT6tWn2d...
# data {'artist_followers': 2984088, 'artist_popularity': 74, 'album_type': 'album', 'label': 'Show Dog Distribution Deal'}
# Fetching 3gD7i7ZxHqIKQa6IEn202O...
# data {'artist_followers': 331342, 'artist_popularity': 59, 'album_type': 'album', 'label': 'Room 8 Records'}
# Fetching 4NS4KhXcdzd0zlX1HNIvoy...
# data {'artist_followers': 853817, 'artist_popularity': 64, 'album_type': 'compilation', 'label': 'ATO Records'}
# Fetching 63puNJX3U2WTPNexLnFQ4p...
# data {'artist_followers': 2718726, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Show Dog Universal Music'}
# Progress saved at row 8260
# Fetching 5k8WJt3VfJhuSVgml2nKGm...
# data {'artist_followers': 272843, 'artist_popularity': 52, 'album_type': 'album', 'label': 'BIG Label Records'}
# Fetching 6UJuulWAyRggY5yx9YXIqS...
# data {'artist_followers': 273970, 'artist_popularity': 55, 'album_type': 'single', 'label': 'Stoney Creek Records'}
# Fetching 5bA26v8eeZrbHJpD4YPKAX...
# data {'artist_followers': 19500, 'artist_popularity': 35, 'album_type': 'album', 'label': 'RLG/Legacy'}
# Fetching 2qM1i7ZYogLcQOxmsJZkiZ...
# data {'artist_followers': 56492, 'artist_popularity': 38, 'album_type': 'single', 'label': 'Bottoms Up Records'}
# Fetching 69dqjNk9eMQPfOnk5qx0Jc...
# data {'artist_followers': 133748, 'artist_popularity': 39, 'album_type': 'single', 'label': 'Wheelhouse Records'}
# Fetching 5aCY2Tv68Wudcr0f9BIHXh...
# data {'artist_followers': 339346, 'artist_popularity': 51, 'album_type': 'album', 'label': 'Big Machine Label Group'}
# Fetching 2dLbkll4gX6GC5iwToDeth...
# data {'artist_followers': 81891, 'artist_popularity': 30, 'album_type': 'album', 'label': 'Psychopathic'}
# Progress saved at row 8300
# Fetching 33YBSsuORzJ7STD74wFaal...
# data {'artist_followers': 841772, 'artist_popularity': 59, 'album_type': 'compilation', 'label': 'MCA Nashville'}
# Fetching 6TiOwROscxTm2fiGAOvJ1E...
# data {'artist_followers': 2541627, 'artist_popularity': 68, 'album_type': 'album', 'label': 'Broken Bow Records'}
# Fetching 0zJX5uqpDt4ThIctFcYVcN...
# data {'artist_followers': 2554473, 'artist_popularity': 73, 'album_type': 'compilation', 'label': 'Columbia/Legacy'}
# Fetching 5ZSNbq1oIjTZhPY0S8A3NK...
# data {'artist_followers': 884576, 'artist_popularity': 72, 'album_type': 'single', 'label': 'Columbia Nashville'}
# Fetching 35oJ1q6IEwpMEPPVtyrAWc...
# data {'artist_followers': 1890003, 'artist_popularity': 71, 'album_type': 'album', 'label': 'Curb Records'}
# Fetching 7zJgdxw73TAyYPPlkpiXBB...
# data {'artist_followers': 19169, 'artist_popularity': 25, 'album_type': 'single', 'label': 'Sea Gayle Records'}
# Fetching 7GZRUcgcXtUWkUwnx7SLkz...
# data {'artist_followers': 2554473, 'artist_popularity': 73, 'album_type': 'compilation', 'label': 'Columbia Nashville Legacy'}
# Fetching 6UoxIDMgtu1VXOBaBIZPbT...
# data {'artist_followers': 1649540, 'artist_popularity': 68, 'album_type': 'album', 'label': 'Gaither Music Group, LLC'}
# Fetching 6ioWVLiVdOLtpKiz8SFRmN...
# data {'artist_followers': 1335167, 'artist_popularity': 80, 'album_type': 'single', 'label': 'BMLG Records'}
# Fetching 18HjTiUz8CapH4BFB0Jrwz...
# data {'artist_followers': 544947, 'artist_popularity': 64, 'album_type': 'album', 'label': 'Big Machine Records, LLC'}
# Progress saved at row 8310
# ✅ Dataset enriched successfully (audio features untouched).
